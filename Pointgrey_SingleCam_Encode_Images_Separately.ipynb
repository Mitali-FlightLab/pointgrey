# %%
import PySpin
import numpy as np
from PIL import Image

NUM_IMAGES = 12000  # Number of images to capture
TRIGGER_SOURCE = 'Line3'  # Trigger source to Line3 (green wire)

class TriggerType:
    HARDWARE = 2

CHOSEN_TRIGGER = TriggerType.HARDWARE

def configure_trigger(cam):
    """
    Configures the camera to use a hardware trigger on Line3.
    """
    try:
        # Ensure trigger mode off
        nodemap = cam.GetNodeMap()
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())

        # Set TriggerSelector to FrameStart
        node_trigger_selector = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSelector'))
        node_trigger_selector_framestart = node_trigger_selector.GetEntryByName('FrameStart')
        node_trigger_selector.SetIntValue(node_trigger_selector_framestart.GetValue())

        # Select trigger source
        node_trigger_source = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSource'))
        node_trigger_source_hardware = node_trigger_source.GetEntryByName(TRIGGER_SOURCE)
        node_trigger_source.SetIntValue(node_trigger_source_hardware.GetValue())

        # Set TriggerActivation to RisingEdge
        node_trigger_activation = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerActivation'))
        node_trigger_activation_risingedge = node_trigger_activation.GetEntryByName('RisingEdge')
        node_trigger_activation.SetIntValue(node_trigger_activation_risingedge.GetValue())

        # Turn trigger mode on
        node_trigger_mode_on = node_trigger_mode.GetEntryByName('On')
        node_trigger_mode.SetIntValue(node_trigger_mode_on.GetValue())

        print('Trigger configured to hardware (Line3) with rising edge activation.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def grab_next_image_by_trigger(cam):
    """
    Waits for hardware trigger to capture image.
    """
    try:
        # Wait for hardware trigger to capture image
        print('Waiting for hardware trigger...')
        image_result = cam.GetNextImage()

        if image_result.IsIncomplete():
            print('Image incomplete with image status %d ...' % image_result.GetImageStatus())
        else:
            print('Image grabbed successfully.')
            return image_result

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

    return None

def acquire_images(cam, nodemap, nodemap_tldevice):
    """
    Acquires images from the camera and stores them as numpy arrays.
    """
    try:
        images = []  # List to store numpy arrays of images

        # Set acquisition mode to continuous
        node_acquisition_mode = PySpin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        node_acquisition_mode.SetIntValue(node_acquisition_mode_continuous.GetValue())

        # Begin acquiring images
        cam.BeginAcquisition()
        print('Acquiring images...')

        # Retrieve device serial number for filename
        device_serial_number = ''
        node_device_serial_number = PySpin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if PySpin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()

        # Retrieve and store images as numpy arrays
        for i in range(NUM_IMAGES):
            image_result = grab_next_image_by_trigger(cam)
            if image_result:
                # Convert image data to numpy array
                image_converted = image_result.GetNDArray()

                # Append numpy array to list
                images.append(image_converted)

                print(f'Image {i} grabbed successfully.')

                # Release image
                image_result.Release()
            else:
                print('Failed to grab image.')

        # End acquisition
        cam.EndAcquisition()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

    return images

def reset_trigger(nodemap):
    """
    Returns the camera to a normal state by turning off trigger mode.
    """
    try:
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())
        print('Trigger mode disabled.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def print_device_info(nodemap):
    """
    Prints the device information of the camera.
    """
    print('* DEVICE INFORMATION *\n')
    try:
        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))
        if PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print(f'{node_feature.GetName()}: {node_feature.ToString() if PySpin.IsReadable(node_feature) else "Node not readable"}')
        else:
            print('Device control information not readable.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def run_single_camera(cam):
    """
    Runs the example on a single camera.
    """
    try:
        # Retrieve TL device nodemap and print device information
        nodemap_tldevice = cam.GetTLDeviceNodeMap()
        print_device_info(nodemap_tldevice)

        # Initialize camera
        cam.Init()

        # Retrieve GenICam nodemap
        nodemap = cam.GetNodeMap()

        # Configure trigger
        if not configure_trigger(cam):
            return False

        # Acquire images
        images = acquire_images(cam, nodemap, nodemap_tldevice)

        # Reset trigger
        reset_trigger(nodemap)

        # Deinitialize camera
        cam.DeInit()

        return images

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

def main():
    """
    Main entry point for the example.
    """
    try:
        # Retrieve singleton reference to system object
        system = PySpin.System.GetInstance()

        # Retrieve list of cameras from the system
        cam_list = system.GetCameras()
        num_cameras = cam_list.GetSize()

        print(f'Number of cameras detected: {num_cameras}')

        # Finish if there are no cameras
        if num_cameras == 0:
            cam_list.Clear()
            system.ReleaseInstance()
            print('Not enough cameras!')
            return None

        # Run example on each camera
        all_images = []
        for i, cam in enumerate(cam_list):
            print(f'Running example for camera {i}...')
            images = run_single_camera(cam)
            if images:
                all_images.extend(images)
            print(f'Camera {i} example complete...')

        # Clear camera list before releasing system
        cam_list.Clear()

        # Release system instance
        system.ReleaseInstance()

        # Save images as JPEG files
        save_images(all_images)

        return all_images

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

def save_images(images):
    """
    Save numpy arrays as JPEG images.
    """
    try:
        for i, img in enumerate(images):
            # Convert numpy array to Pillow Image
            img_pil = Image.fromarray(img)

            # Save image
            filename = f'image_{i}.jpg'
            img_pil.save(filename)

            print(f'Image saved as {filename}')

    except Exception as ex:
        print('Error saving images:', ex)

if __name__ == '__main__':
    main()
# Out:
# Number of cameras detected: 1
# Running example for camera 0...
# * DEVICE INFORMATION *
#
# DeviceID: USB\VID_1E10&PID_4000&MI_00\6&2A5D0DF9&0&0000_0
# DeviceSerialNumber: 16290112
# DeviceUserID:
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-13Y3M
# DeviceVersion: 1808.0.120.0
# DeviceBootloaderVersion: Node not readable
# DeviceType: USB3Vision
# DeviceDisplayName: FLIR Blackfly S BFS-U3-13Y3M
# DeviceAccessStatus: OpenReadWrite
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&2A5D0DF9&0&0000
# DeviceLocation: 0000.0014.0000.021.000.000.000.000.000
# DeviceCurrentSpeed: SuperSpeed
# DeviceU3VProtocol: 1
# DevicePortId: 21
# GenICamXMLLocation: Device
# GenICamXMLPath:
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# Trigger configured to hardware (Line3) with rising edge activation.
# Acquiring images...
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image
grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 356 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 357 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 358 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 359 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 360 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 361 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 362 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 363 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 364 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 365 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 366 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 367 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 368 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 369 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 370 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 371 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 372 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 373 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 374 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 375 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 376 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 377 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 378 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 379 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 380 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 381 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 382 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 383 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 384 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 385 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 386 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 387 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 388 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 389 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 390 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 391 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 392 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 393 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 394 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 395 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 396 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 397 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 398 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 399 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 400 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 401 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 402 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 403 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 404 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 405 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 406 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 407 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 408 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 409 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 410 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 411 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 412 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 413 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 414 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 415 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 416 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 417 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 418 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 419 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 420 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 421 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 422 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 423 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 424 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 425 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 426 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 427 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 428 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 429 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 430 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 431 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 432 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 433 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 434 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 435 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 436 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 437 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 438 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 439 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 440 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 441 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 442 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 443 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 444 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 445 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 446 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 447 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 448 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 449 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 450 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 451 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 452 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 453 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 454 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 455 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 456 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 457 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 458 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 459 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 460 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 461 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 462 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 463 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 464 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 465 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 466 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 467 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 468 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 469 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 470 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 471 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 472 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 473 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 474 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 475 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 476 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 477 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 478 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 479 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 480 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 481 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 482 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 483 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 484 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 485 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 486 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 487 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 488 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 489 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 490 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 491 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 492 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 493 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 494 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 495 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 496 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 497 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 498 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 499 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 500 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 501 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 502 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 503 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 504 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 505 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 506 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 507 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 508 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 509 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 510 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 511 grabbed successfully.
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image 512 grabbed successfully.
# Waiting for hardware trigger...
# ...
# Image saved as image_11484.jpg
# Image saved as image_11485.jpg
# Image saved as image_11486.jpg
# Image saved as image_11487.jpg
# Image saved as image_11488.jpg
# Image saved as image_11489.jpg
# Image saved as image_11490.jpg
# Image saved as image_11491.jpg
# Image saved as image_11492.jpg
# Image saved as image_11493.jpg
# Image saved as image_11494.jpg
# Image saved as image_11495.jpg
# Image saved as image_11496.jpg
# Image saved as image_11497.jpg
# Image saved as image_11498.jpg
# Image saved as image_11499.jpg
# Image saved as image_11500.jpg
# Image saved as image_11501.jpg
# Image saved as image_11502.jpg
# Image saved as image_11503.jpg
# Image saved as image_11504.jpg
# Image saved as image_11505.jpg
# Image saved as image_11506.jpg
# Image saved as image_11507.jpg
# Image saved as image_11508.jpg
# Image saved as image_11509.jpg
# Image saved as image_11510.jpg
# Image saved as image_11511.jpg
# Image saved as image_11512.jpg
# Image saved as image_11513.jpg
# Image saved as image_11514.jpg
# Image saved as image_11515.jpg
# Image saved as image_11516.jpg
# Image saved as image_11517.jpg
# Image saved as image_11518.jpg
# Image saved as image_11519.jpg
# Image saved as image_11520.jpg
# Image saved as image_11521.jpg
# Image saved as image_11522.jpg
# Image saved as image_11523.jpg
# Image saved as image_11524.jpg
# Image saved as image_11525.jpg
# Image saved as image_11526.jpg
# Image saved as image_11527.jpg
# Image saved as image_11528.jpg
# Image saved as image_11529.jpg
# Image saved as image_11530.jpg
# Image saved as image_11531.jpg
# Image saved as image_11532.jpg
# Image saved as image_11533.jpg
# Image saved as image_11534.jpg
# Image saved as image_11535.jpg
# Image saved as image_11536.jpg
# Image saved as image_11537.jpg
# Image saved as image_11538.jpg
# Image saved as image_11539.jpg
# Image saved as image_11540.jpg
# Image saved as image_11541.jpg
# Image saved as image_11542.jpg
# Image saved as image_11543.jpg
# Image saved as image_11544.jpg
# Image saved as image_11545.jpg
# Image saved as image_11546.jpg
# Image saved as image_11547.jpg
# Image saved as image_11548.jpg
# Image saved as image_11549.jpg
# Image saved as image_11550.jpg
# Image saved as image_11551.jpg
# Image saved as image_11552.jpg
# Image saved as image_11553.jpg
# Image saved as image_11554.jpg
# Image saved as image_11555.jpg
# Image saved as image_11556.jpg
# Image saved as image_11557.jpg
# Image saved as image_11558.jpg
# Image saved as image_11559.jpg
# Image saved as image_11560.jpg
# Image saved as image_11561.jpg
# Image saved as image_11562.jpg
# Image saved as image_11563.jpg
# Image saved as image_11564.jpg
# Image saved as image_11565.jpg
# Image saved as image_11566.jpg
# Image saved as image_11567.jpg
# Image saved as image_11568.jpg
# Image saved as image_11569.jpg
# Image saved as image_11570.jpg
# Image saved as image_11571.jpg
# Image saved as image_11572.jpg
# Image saved as image_11573.jpg
# Image saved as image_11574.jpg
# Image saved as image_11575.jpg
# Image saved as image_11576.jpg
# Image saved as image_11577.jpg
# Image saved as image_11578.jpg
# Image saved as image_11579.jpg
# Image saved as image_11580.jpg
# Image saved as image_11581.jpg
# Image saved as image_11582.jpg
# Image saved as image_11583.jpg
# Image saved as image_11584.jpg
# Image saved as image_11585.jpg
# Image saved as image_11586.jpg
# Image saved as image_11587.jpg
# Image saved as image_11588.jpg
# Image saved as image_11589.jpg
# Image saved as image_11590.jpg
# Image saved as image_11591.jpg
# Image saved as image_11592.jpg
# Image saved as image_11593.jpg
# Image saved as image_11594.jpg
# Image saved as image_11595.jpg
# Image saved as image_11596.jpg
# Image saved as image_11597.jpg
# Image saved as image_11598.jpg
# Image saved as image_11599.jpg
# Image saved as image_11600.jpg
# Image saved as image_11601.jpg
# Image saved as image_11602.jpg
# Image saved as image_11603.jpg
# Image saved as image_11604.jpg
# Image saved as image_11605.jpg
# Image saved as image_11606.jpg
# Image saved as image_11607.jpg
# Image saved as image_11608.jpg
# Image saved as image_11609.jpg
# Image saved as image_11610.jpg
# Image saved as image_11611.jpg
# Image saved as image_11612.jpg
# Image saved as image_11613.jpg
# Image saved as image_11614.jpg
# Image saved as image_11615.jpg
# Image saved as image_11616.jpg
# Image saved as image_11617.jpg
# Image saved as image_11618.jpg
# Image saved as image_11619.jpg
# Image saved as image_11620.jpg
# Image saved as image_11621.jpg
# Image saved as image_11622.jpg
# Image saved as image_11623.jpg
# Image saved as image_11624.jpg
# Image saved as image_11625.jpg
# Image saved as image_11626.jpg
# Image saved as image_11627.jpg
# Image saved as image_11628.jpg
# Image saved as image_11629.jpg
# Image saved as image_11630.jpg
# Image saved as image_11631.jpg
# Image saved as image_11632.jpg
# Image saved as image_11633.jpg
# Image saved as image_11634.jpg
# Image saved as image_11635.jpg
# Image saved as image_11636.jpg
# Image saved as image_11637.jpg
# Image saved as image_11638.jpg
# Image saved as image_11639.jpg
# Image saved as image_11640.jpg
# Image saved as image_11641.jpg
# Image saved as image_11642.jpg
# Image saved as image_11643.jpg
# Image saved as image_11644.jpg
# Image saved as image_11645.jpg
# Image saved as image_11646.jpg
# Image saved as image_11647.jpg
# Image saved as image_11648.jpg
# Image saved as image_11649.jpg
# Image saved as image_11650.jpg
# Image saved as image_11651.jpg
# Image saved as image_11652.jpg
# Image saved as image_11653.jpg
# Image saved as image_11654.jpg
# Image saved as image_11655.jpg
# Image saved as image_11656.jpg
# Image saved as image_11657.jpg
# Image saved as image_11658.jpg
# Image saved as image_11659.jpg
# Image saved as image_11660.jpg
# Image saved as image_11661.jpg
# Image saved as image_11662.jpg
# Image saved as image_11663.jpg
# Image saved as image_11664.jpg
# Image saved as image_11665.jpg
# Image saved as image_11666.jpg
# Image saved as image_11667.jpg
# Image saved as image_11668.jpg
# Image saved as image_11669.jpg
# Image saved as image_11670.jpg
# Image saved as image_11671.jpg
# Image saved as image_11672.jpg
# Image saved as image_11673.jpg
# Image saved as image_11674.jpg
# Image saved as image_11675.jpg
# Image saved as image_11676.jpg
# Image saved as image_11677.jpg
# Image saved as image_11678.jpg
# Image saved as image_11679.jpg
# Image saved as image_11680.jpg
# Image saved as image_11681.jpg
# Image saved as image_11682.jpg
# Image saved as image_11683.jpg
# Image saved as image_11684.jpg
# Image saved as image_11685.jpg
# Image saved as image_11686.jpg
# Image saved as image_11687.jpg
# Image saved as image_11688.jpg
# Image saved as image_11689.jpg
# Image saved as image_11690.jpg
# Image saved as image_11691.jpg
# Image saved as image_11692.jpg
# Image saved as image_11693.jpg
# Image saved as image_11694.jpg
# Image saved as image_11695.jpg
# Image saved as image_11696.jpg
# Image saved as image_11697.jpg
# Image saved as image_11698.jpg
# Image saved as image_11699.jpg
# Image saved as image_11700.jpg
# Image saved as image_11701.jpg
# Image saved as image_11702.jpg
# Image saved as image_11703.jpg
# Image saved as image_11704.jpg
# Image saved as image_11705.jpg
# Image saved as image_11706.jpg
# Image saved as image_11707.jpg
# Image saved as image_11708.jpg
# Image saved as image_11709.jpg
# Image saved as image_11710.jpg
# Image saved as image_11711.jpg
# Image saved as image_11712.jpg
# Image saved as image_11713.jpg
# Image saved as image_11714.jpg
# Image saved as image_11715.jpg
# Image saved as image_11716.jpg
# Image saved as image_11717.jpg
# Image saved as image_11718.jpg
# Image saved as image_11719.jpg
# Image saved as image_11720.jpg
# Image saved as image_11721.jpg
# Image saved as image_11722.jpg
# Image saved as image_11723.jpg
# Image saved as image_11724.jpg
# Image saved as image_11725.jpg
# Image saved as image_11726.jpg
# Image saved as image_11727.jpg
# Image saved as image_11728.jpg
# Image saved as image_11729.jpg
# Image saved as image_11730.jpg
# Image saved as image_11731.jpg
# Image saved as image_11732.jpg
# Image saved as image_11733.jpg
# Image saved as image_11734.jpg
# Image saved as image_11735.jpg
# Image saved as image_11736.jpg
# Image saved as image_11737.jpg
# Image saved as image_11738.jpg
# Image saved as image_11739.jpg
# Image saved as image_11740.jpg
# Image saved as image_11741.jpg
# Image saved as image_11742.jpg
# Image saved as image_11743.jpg
# Image saved as image_11744.jpg
# Image saved as image_11745.jpg
# Image saved as image_11746.jpg
# Image saved as image_11747.jpg
# Image saved as image_11748.jpg
# Image saved as image_11749.jpg
# Image saved as image_11750.jpg
# Image saved as image_11751.jpg
# Image saved as image_11752.jpg
# Image saved as image_11753.jpg
# Image saved as image_11754.jpg
# Image saved as image_11755.jpg
# Image saved as image_11756.jpg
# Image saved as image_11757.jpg
# Image saved as image_11758.jpg
# Image saved as image_11759.jpg
# Image saved as image_11760.jpg
# Image saved as image_11761.jpg
# Image saved as image_11762.jpg
# Image saved as image_11763.jpg
# Image saved as image_11764.jpg
# Image saved as image_11765.jpg
# Image saved as image_11766.jpg
# Image saved as image_11767.jpg
# Image saved as image_11768.jpg
# Image saved as image_11769.jpg
# Image saved as image_11770.jpg
# Image saved as image_11771.jpg
# Image saved as image_11772.jpg
# Image saved as image_11773.jpg
# Image saved as image_11774.jpg
# Image saved as image_11775.jpg
# Image saved as image_11776.jpg
# Image saved as image_11777.jpg
# Image saved as image_11778.jpg
# Image saved as image_11779.jpg
# Image saved as image_11780.jpg
# Image saved as image_11781.jpg
# Image saved as image_11782.jpg
# Image saved as image_11783.jpg
# Image saved as image_11784.jpg
# Image saved as image_11785.jpg
# Image saved as image_11786.jpg
# Image saved as image_11787.jpg
# Image saved as image_11788.jpg
# Image saved as image_11789.jpg
# Image saved as image_11790.jpg
# Image saved as image_11791.jpg
# Image saved as image_11792.jpg
# Image saved as image_11793.jpg
# Image saved as image_11794.jpg
# Image saved as image_11795.jpg
# Image saved as image_11796.jpg
# Image saved as image_11797.jpg
# Image saved as image_11798.jpg
# Image saved as image_11799.jpg
# Image saved as image_11800.jpg
# Image saved as image_11801.jpg
# Image saved as image_11802.jpg
# Image saved as image_11803.jpg
# Image saved as image_11804.jpg
# Image saved as image_11805.jpg
# Image saved as image_11806.jpg
# Image saved as image_11807.jpg
# Image saved as image_11808.jpg
# Image saved as image_11809.jpg
# Image saved as image_11810.jpg
# Image saved as image_11811.jpg
# Image saved as image_11812.jpg
# Image saved as image_11813.jpg
# Image saved as image_11814.jpg
# Image saved as image_11815.jpg
# Image saved as image_11816.jpg
# Image saved as image_11817.jpg
# Image saved as image_11818.jpg
# Image saved as image_11819.jpg
# Image saved as image_11820.jpg
# Image saved as image_11821.jpg
# Image saved as image_11822.jpg
# Image saved as image_11823.jpg
# Image saved as image_11824.jpg
# Image saved as image_11825.jpg
# Image saved as image_11826.jpg
# Image saved as image_11827.jpg
# Image saved as image_11828.jpg
# Image saved as image_11829.jpg
# Image saved as image_11830.jpg
# Image saved as image_11831.jpg
# Image saved as image_11832.jpg
# Image saved as image_11833.jpg
# Image saved as image_11834.jpg
# Image saved as image_11835.jpg
# Image saved as image_11836.jpg
# Image saved as image_11837.jpg
# Image saved as image_11838.jpg
# Image saved as image_11839.jpg
# Image saved as image_11840.jpg
# Image saved as image_11841.jpg
# Image saved as image_11842.jpg
# Image saved as image_11843.jpg
# Image saved as image_11844.jpg
# Image saved as image_11845.jpg
# Image saved as image_11846.jpg
# Image saved as image_11847.jpg
# Image saved as image_11848.jpg
# Image saved as image_11849.jpg
# Image saved as image_11850.jpg
# Image saved as image_11851.jpg
# Image saved as image_11852.jpg
# Image saved as image_11853.jpg
# Image saved as image_11854.jpg
# Image saved as image_11855.jpg
# Image saved as image_11856.jpg
# Image saved as image_11857.jpg
# Image saved as image_11858.jpg
# Image saved as image_11859.jpg
# Image saved as image_11860.jpg
# Image saved as image_11861.jpg
# Image saved as image_11862.jpg
# Image saved as image_11863.jpg
# Image saved as image_11864.jpg
# Image saved as image_11865.jpg
# Image saved as image_11866.jpg
# Image saved as image_11867.jpg
# Image saved as image_11868.jpg
# Image saved as image_11869.jpg
# Image saved as image_11870.jpg
# Image saved as image_11871.jpg
# Image saved as image_11872.jpg
# Image saved as image_11873.jpg
# Image saved as image_11874.jpg
# Image saved as image_11875.jpg
# Image saved as image_11876.jpg
# Image saved as image_11877.jpg
# Image saved as image_11878.jpg
# Image saved as image_11879.jpg
# Image saved as image_11880.jpg
# Image saved as image_11881.jpg
# Image saved as image_11882.jpg
# Image saved as image_11883.jpg
# Image saved as image_11884.jpg
# Image saved as image_11885.jpg
# Image saved as image_11886.jpg
# Image saved as image_11887.jpg
# Image saved as image_11888.jpg
# Image saved as image_11889.jpg
# Image saved as image_11890.jpg
# Image saved as image_11891.jpg
# Image saved as image_11892.jpg
# Image saved as image_11893.jpg
# Image saved as image_11894.jpg
# Image saved as image_11895.jpg
# Image saved as image_11896.jpg
# Image saved as image_11897.jpg
# Image saved as image_11898.jpg
# Image saved as image_11899.jpg
# Image saved as image_11900.jpg
# Image saved as image_11901.jpg
# Image saved as image_11902.jpg
# Image saved as image_11903.jpg
# Image saved as image_11904.jpg
# Image saved as image_11905.jpg
# Image saved as image_11906.jpg
# Image saved as image_11907.jpg
# Image saved as image_11908.jpg
# Image saved as image_11909.jpg
# Image saved as image_11910.jpg
# Image saved as image_11911.jpg
# Image saved as image_11912.jpg
# Image saved as image_11913.jpg
# Image saved as image_11914.jpg
# Image saved as image_11915.jpg
# Image saved as image_11916.jpg
# Image saved as image_11917.jpg
# Image saved as image_11918.jpg
# Image saved as image_11919.jpg
# Image saved as image_11920.jpg
# Image saved as image_11921.jpg
# Image saved as image_11922.jpg
# Image saved as image_11923.jpg
# Image saved as image_11924.jpg
# Image saved as image_11925.jpg
# Image saved as image_11926.jpg
# Image saved as image_11927.jpg
# Image saved as image_11928.jpg
# Image saved as image_11929.jpg
# Image saved as image_11930.jpg
# Image saved as image_11931.jpg
# Image saved as image_11932.jpg
# Image saved as image_11933.jpg
# Image saved as image_11934.jpg
# Image saved as image_11935.jpg
# Image saved as image_11936.jpg
# Image saved as image_11937.jpg
# Image saved as image_11938.jpg
# Image saved as image_11939.jpg
# Image saved as image_11940.jpg
# Image saved as image_11941.jpg
# Image saved as image_11942.jpg
# Image saved as image_11943.jpg
# Image saved as image_11944.jpg
# Image saved as image_11945.jpg
# Image saved as image_11946.jpg
# Image saved as image_11947.jpg
# Image saved as image_11948.jpg
# Image saved as image_11949.jpg
# Image saved as image_11950.jpg
# Image saved as image_11951.jpg
# Image saved as image_11952.jpg
# Image saved as image_11953.jpg
# Image saved as image_11954.jpg
# Image saved as image_11955.jpg
# Image saved as image_11956.jpg
# Image saved as image_11957.jpg
# Image saved as image_11958.jpg
# Image saved as image_11959.jpg
# Image saved as image_11960.jpg
# Image saved as image_11961.jpg
# Image saved as image_11962.jpg
# Image saved as image_11963.jpg
# Image saved as image_11964.jpg
# Image saved as image_11965.jpg
# Image saved as image_11966.jpg
# Image saved as image_11967.jpg
# Image saved as image_11968.jpg
# Image saved as image_11969.jpg
# Image saved as image_11970.jpg
# Image saved as image_11971.jpg
# Image saved as image_11972.jpg
# Image saved as image_11973.jpg
# Image saved as image_11974.jpg
# Image saved as image_11975.jpg
# Image saved as image_11976.jpg
# Image saved as image_11977.jpg
# Image saved as image_11978.jpg
# Image saved as image_11979.jpg
# Image saved as image_11980.jpg
# Image saved as image_11981.jpg
# Image saved as image_11982.jpg
# Image saved as image_11983.jpg
# Image saved as image_11984.jpg
# Image saved as image_11985.jpg
# Image saved as image_11986.jpg
# Image saved as image_11987.jpg
# Image saved as image_11988.jpg
# Image saved as image_11989.jpg
# Image saved as image_11990.jpg
# Image saved as image_11991.jpg
# Image saved as image_11992.jpg
# Image saved as image_11993.jpg
# Image saved as image_11994.jpg
# Image saved as image_11995.jpg
# Image saved as image_11996.jpg
# Image saved as image_11997.jpg
# Image saved as image_11998.jpg
# Image saved as image_11999.jpg

# %% [markdown]
# SAVE IMAGES IN RAM AS NUMP ARRAYS AND THEN IN THEN DUMP IN THE CPU

# %%
import PySpin
import numpy as np
from PIL import Image

NUM_IMAGES = 10  # Number of images to capture
TRIGGER_SOURCE = 'Line3'  # Trigger source to Line3 (green wire)

class TriggerType:
    HARDWARE = 2

CHOSEN_TRIGGER = TriggerType.HARDWARE

def configure_trigger(cam):
    """
    Configures the camera to use a hardware trigger on Line3.
    """
    try:
        nodemap = cam.GetNodeMap()
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())

        node_trigger_selector = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSelector'))
        node_trigger_selector_framestart = node_trigger_selector.GetEntryByName('FrameStart')
        node_trigger_selector.SetIntValue(node_trigger_selector_framestart.GetValue())

        node_trigger_source = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSource'))
        node_trigger_source_hardware = node_trigger_source.GetEntryByName(TRIGGER_SOURCE)
        node_trigger_source.SetIntValue(node_trigger_source_hardware.GetValue())

        node_trigger_activation = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerActivation'))
        node_trigger_activation_risingedge = node_trigger_activation.GetEntryByName('RisingEdge')
        node_trigger_activation.SetIntValue(node_trigger_activation_risingedge.GetValue())

        node_trigger_mode_on = node_trigger_mode.GetEntryByName('On')
        node_trigger_mode.SetIntValue(node_trigger_mode_on.GetValue())

        print('Trigger configured to hardware (Line3) with rising edge activation.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def grab_next_image_by_trigger(cam):
    """
    Waits for hardware trigger to capture image.
    """
    try:
        print('Waiting for hardware trigger...')
        image_result = cam.GetNextImage()

        if image_result.IsIncomplete():
            print('Image incomplete with image status %d ...' % image_result.GetImageStatus())
        else:
            print('Image grabbed successfully.')
            return image_result

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

    return None

def save_image(image_result, filename):
    """
    Saves the captured image to disk as a JPEG file.
    """
    try:
        # Convert image data to numpy array
        image_np = image_result.GetNDArray()
        # Convert numpy array to Pillow Image
        img_pil = Image.fromarray(image_np)
        # Save image
        img_pil.save(filename)
        print(f'Image saved as {filename}')
    except Exception as ex:
        print(f'Error saving image {filename}:', ex)

def acquire_images(cam, nodemap, nodemap_tldevice):
    """
    Acquires images from the camera and processes them immediately.
    """
    try:
        node_acquisition_mode = PySpin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        node_acquisition_mode.SetIntValue(node_acquisition_mode_continuous.GetValue())

        cam.BeginAcquisition()
        print('Acquiring images...')

        device_serial_number = ''
        node_device_serial_number = PySpin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if PySpin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()

        for i in range(NUM_IMAGES):
            image_result = grab_next_image_by_trigger(cam)
            if image_result:
                filename = f'Trigger-{device_serial_number}-{i}.jpg'
                save_image(image_result, filename)
                image_result.Release()
            else:
                print('Failed to grab image.')

        cam.EndAcquisition()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def reset_trigger(nodemap):
    """
    Returns the camera to a normal state by turning off trigger mode.
    """
    try:
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())
        print('Trigger mode disabled.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def print_device_info(nodemap):
    """
    Prints the device information of the camera.
    """
    print('* DEVICE INFORMATION *\n')
    try:
        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))
        if PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print(f'{node_feature.GetName()}: {node_feature.ToString() if PySpin.IsReadable(node_feature) else "Node not readable"}')
        else:
            print('Device control information not readable.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def run_single_camera(cam):
    """
    Runs the example on a single camera.
    """
    try:
        nodemap_tldevice = cam.GetTLDeviceNodeMap()
        print_device_info(nodemap_tldevice)

        cam.Init()

        nodemap = cam.GetNodeMap()

        if not configure_trigger(cam):
            return False

        acquire_images(cam, nodemap, nodemap_tldevice)

        reset_trigger(nodemap)

        cam.DeInit()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def main():
    """
    Main entry point for the example.
    """
    try:
        system = PySpin.System.GetInstance()

        cam_list = system.GetCameras()
        num_cameras = cam_list.GetSize()

        print(f'Number of cameras detected: {num_cameras}')

        if num_cameras == 0:
            cam_list.Clear()
            system.ReleaseInstance()
            print('Not enough cameras!')
            return False

        for i, cam in enumerate(cam_list):
            print(f'Running example for camera {i}...')
            run_single_camera(cam)
            print(f'Camera {i} example complete...')

        cam_list.Clear()

        system.ReleaseInstance()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

if __name__ == '__main__':
    main()

# %% [markdown]
# with the above code, the RAM usage was hitting 96% and then the CPU was going to 50% as the ram was getting emptied

# %% [markdown]
# USE RAM AS BUFFER

# %%
import PySpin
import numpy as np
from PIL import Image
import threading
import queue
import time

NUM_IMAGES = 12000  # Number of images to capture
TRIGGER_SOURCE = 'Line3'  # Trigger source to Line3 (green wire)
BUFFER_SIZE = 5000  # Size of the buffer

class TriggerType:
    HARDWARE = 2

CHOSEN_TRIGGER = TriggerType.HARDWARE

def configure_trigger(cam):
    """
    Configures the camera to use a hardware trigger on Line3.
    """
    try:
        nodemap = cam.GetNodeMap()
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())

        node_trigger_selector = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSelector'))
        node_trigger_selector_framestart = node_trigger_selector.GetEntryByName('FrameStart')
        node_trigger_selector.SetIntValue(node_trigger_selector_framestart.GetValue())

        node_trigger_source = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSource'))
        node_trigger_source_hardware = node_trigger_source.GetEntryByName(TRIGGER_SOURCE)
        node_trigger_source.SetIntValue(node_trigger_source_hardware.GetValue())

        node_trigger_activation = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerActivation'))
        node_trigger_activation_risingedge = node_trigger_activation.GetEntryByName('RisingEdge')
        node_trigger_activation.SetIntValue(node_trigger_activation_risingedge.GetValue())

        node_trigger_mode_on = node_trigger_mode.GetEntryByName('On')
        node_trigger_mode.SetIntValue(node_trigger_mode_on.GetValue())

        print('Trigger configured to hardware (Line3) with rising edge activation.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def grab_next_image_by_trigger(cam):
    """
    Waits for hardware trigger to capture image.
    """
    try:
        print('Waiting for hardware trigger...')
        image_result = cam.GetNextImage()

        if image_result.IsIncomplete():
            print('Image incomplete with image status %d ...' % image_result.GetImageStatus())
        else:
            print('Image grabbed successfully.')
            return image_result

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

    return None

def save_image(image_np, filename):
    """
    Saves the captured image to disk as a JPEG file.
    """
    try:
        img_pil = Image.fromarray(image_np)
        img_pil.save(filename)
        print(f'Image saved as {filename}')
    except Exception as ex:
        print(f'Error saving image {filename}:', ex)

def acquire_images(cam, nodemap, nodemap_tldevice, image_queue):
    """
    Acquires images from the camera and puts them in a queue for processing.
    """
    try:
        node_acquisition_mode = PySpin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        node_acquisition_mode.SetIntValue(node_acquisition_mode_continuous.GetValue())

        cam.BeginAcquisition()
        print('Acquiring images...')

        device_serial_number = ''
        node_device_serial_number = PySpin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if PySpin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()

        for i in range(NUM_IMAGES):
            image_result = grab_next_image_by_trigger(cam)
            if image_result:
                image_np = image_result.GetNDArray()
                filename = f'Trigger-{device_serial_number}-{i}.jpg'
                image_queue.put((image_np, filename))
                image_result.Release()
            else:
                print('Failed to grab image.')

        cam.EndAcquisition()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def process_images(image_queue):
    """
    Processes images from the queue and saves them to disk.
    """
    while True:
        image_np, filename = image_queue.get()
        if image_np is None:
            break
        save_image(image_np, filename)
        image_queue.task_done()

def reset_trigger(nodemap):
    """
    Returns the camera to a normal state by turning off trigger mode.
    """
    try:
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())
        print('Trigger mode disabled.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def print_device_info(nodemap):
    """
    Prints the device information of the camera.
    """
    print('* DEVICE INFORMATION *\n')
    try:
        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))
        if PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print(f'{node_feature.GetName()}: {node_feature.ToString() if PySpin.IsReadable(node_feature) else "Node not readable"}')
        else:
            print('Device control information not readable.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def run_single_camera(cam, image_queue):
    """
    Runs the example on a single camera.
    """
    try:
        nodemap_tldevice = cam.GetTLDeviceNodeMap()
        print_device_info(nodemap_tldevice)

        cam.Init()

        nodemap = cam.GetNodeMap()

        if not configure_trigger(cam):
            return False

        acquire_images(cam, nodemap, nodemap_tldevice, image_queue)

        reset_trigger(nodemap)

        cam.DeInit()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def main():
    """
    Main entry point for the example.
    """
    try:
        system = PySpin.System.GetInstance()

        cam_list = system.GetCameras()
        num_cameras = cam_list.GetSize()

        print(f'Number of cameras detected: {num_cameras}')

        if num_cameras == 0:
            cam_list.Clear()
            system.ReleaseInstance()
            print('Not enough cameras!')
            return False

        image_queue = queue.Queue(maxsize=BUFFER_SIZE)
        threads = []

        # Start the image processing thread
        t = threading.Thread(target=process_images, args=(image_queue,))
        t.start()
        threads.append(t)

        for i, cam in enumerate(cam_list):
            print(f'Running example for camera {i}...')
            run_single_camera(cam, image_queue)
            print(f'Camera {i} example complete...')

        # Stop the processing thread
        image_queue.put((None, None))
        for t in threads:
            t.join()

        cam_list.Clear()
        system.ReleaseInstance()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

if __name__ == '__main__':
    main()
# Out:
# Number of cameras detected: 1
# Running example for camera 0...
# * DEVICE INFORMATION *
#
# DeviceID: USB\VID_1E10&PID_4000&MI_00\6&2A5D0DF9&0&0000_0
# DeviceSerialNumber: 16290112
# DeviceUserID:
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-13Y3M
# DeviceVersion: 1808.0.120.0
# DeviceBootloaderVersion: Node not readable
# DeviceType: USB3Vision
# DeviceDisplayName: FLIR Blackfly S BFS-U3-13Y3M
# DeviceAccessStatus: OpenReadWrite
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
