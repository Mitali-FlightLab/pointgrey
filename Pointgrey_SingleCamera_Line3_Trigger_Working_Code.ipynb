# %%
import PySpin
import time
import sys

NUM_IMAGES = 12000  # Number of images to capture
TRIGGER_SOURCE = 'Line3'  # Trigger source to Line3 (green wire)

class TriggerType:
    HARDWARE = 2

CHOSEN_TRIGGER = TriggerType.HARDWARE

def configure_trigger(cam):
    """
    Configures the camera to use a hardware trigger on Line3.
    """
    try:
        # Ensure trigger mode off
        nodemap = cam.GetNodeMap()
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())

        # Set TriggerSelector to FrameStart
        node_trigger_selector = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSelector'))
        node_trigger_selector_framestart = node_trigger_selector.GetEntryByName('FrameStart')
        node_trigger_selector.SetIntValue(node_trigger_selector_framestart.GetValue())

        # Select trigger source
        node_trigger_source = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerSource'))
        node_trigger_source_hardware = node_trigger_source.GetEntryByName(TRIGGER_SOURCE)
        node_trigger_source.SetIntValue(node_trigger_source_hardware.GetValue())

        # Set TriggerActivation to RisingEdge
        node_trigger_activation = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerActivation'))
        node_trigger_activation_risingedge = node_trigger_activation.GetEntryByName('RisingEdge')
        node_trigger_activation.SetIntValue(node_trigger_activation_risingedge.GetValue())

        # Turn trigger mode on
        node_trigger_mode_on = node_trigger_mode.GetEntryByName('On')
        node_trigger_mode.SetIntValue(node_trigger_mode_on.GetValue())

        print('Trigger configured to hardware (Line3) with rising edge activation.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def grab_next_image_by_trigger(cam):
    """
    Waits for hardware trigger to capture image.
    """
    try:
        # Wait for hardware trigger to capture image
        print('Waiting for hardware trigger...')
        image_result = cam.GetNextImage()

        if image_result.IsIncomplete():
            print('Image incomplete with image status %d ...' % image_result.GetImageStatus())
        else:
            print('Image grabbed successfully.')
            return image_result

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return None

    return None

def acquire_images(cam, nodemap, nodemap_tldevice):
    """
    Acquires and saves images from the camera.
    """
    try:
        result = True

        # Set acquisition mode to continuous
        node_acquisition_mode = PySpin.CEnumerationPtr(nodemap.GetNode('AcquisitionMode'))
        node_acquisition_mode_continuous = node_acquisition_mode.GetEntryByName('Continuous')
        node_acquisition_mode.SetIntValue(node_acquisition_mode_continuous.GetValue())

        # Begin acquiring images
        cam.BeginAcquisition()
        print('Acquiring images...')

        # Retrieve device serial number for filename
        device_serial_number = ''
        node_device_serial_number = PySpin.CStringPtr(nodemap_tldevice.GetNode('DeviceSerialNumber'))
        if PySpin.IsReadable(node_device_serial_number):
            device_serial_number = node_device_serial_number.GetValue()

        # Retrieve, convert, and save images
        for i in range(NUM_IMAGES):
            image_result = grab_next_image_by_trigger(cam)
            if image_result:
                # Create a unique filename
                filename = f'Trigger-{device_serial_number}-{i}.jpg'

                # Save image
                image_result.Save(filename)
                print(f'Image saved at {filename}')

                # Release image
                image_result.Release()
            else:
                print('Failed to grab image.')

        # End acquisition
        cam.EndAcquisition()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return result

def reset_trigger(nodemap):
    """
    Returns the camera to a normal state by turning off trigger mode.
    """
    try:
        node_trigger_mode = PySpin.CEnumerationPtr(nodemap.GetNode('TriggerMode'))
        node_trigger_mode_off = node_trigger_mode.GetEntryByName('Off')
        node_trigger_mode.SetIntValue(node_trigger_mode_off.GetValue())
        print('Trigger mode disabled.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def print_device_info(nodemap):
    """
    Prints the device information of the camera.
    """
    print('*** DEVICE INFORMATION ***\n')
    try:
        node_device_information = PySpin.CCategoryPtr(nodemap.GetNode('DeviceInformation'))
        if PySpin.IsReadable(node_device_information):
            features = node_device_information.GetFeatures()
            for feature in features:
                node_feature = PySpin.CValuePtr(feature)
                print(f'{node_feature.GetName()}: {node_feature.ToString() if PySpin.IsReadable(node_feature) else "Node not readable"}')
        else:
            print('Device control information not readable.')

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        return False

    return True

def run_single_camera(cam):
    """
    Runs the example on a single camera.
    """
    try:
        result = True

        # Retrieve TL device nodemap and print device information
        nodemap_tldevice = cam.GetTLDeviceNodeMap()
        result &= print_device_info(nodemap_tldevice)

        # Initialize camera
        cam.Init()

        # Retrieve GenICam nodemap
        nodemap = cam.GetNodeMap()

        # Configure trigger
        if not configure_trigger(cam):
            return False

        # Acquire images
        result &= acquire_images(cam, nodemap, nodemap_tldevice)

        # Reset trigger
        result &= reset_trigger(nodemap)

        # Deinitialize camera
        cam.DeInit()

    except PySpin.SpinnakerException as ex:
        print('Error: %s' % ex)
        result = False

    return result

def main():
    """
    Main entry point for the example.
    """
    result = True

    # Retrieve singleton reference to system object
    system = PySpin.System.GetInstance()

    # Get current library version
    version = system.GetLibraryVersion()
    print(f'Library version: {version.major}.{version.minor}.{version.type}.{version.build}')

    # Retrieve list of cameras from the system
    cam_list = system.GetCameras()
    num_cameras = cam_list.GetSize()

    print(f'Number of cameras detected: {num_cameras}')

    # Finish if there are no cameras
    if num_cameras == 0:
        cam_list.Clear()
        system.ReleaseInstance()
        print('Not enough cameras!')
        return False

    # Run example on each camera
    for i, cam in enumerate(cam_list):
        print(f'Running example for camera {i}...')
        result &= run_single_camera(cam)
        print(f'Camera {i} example complete...')

    # Clear camera list before releasing system
    cam_list.Clear()

    # Release system instance
    system.ReleaseInstance()

    return result

if __name__ == '__main__':
    if main():
        sys.exit(0)
    else:
        sys.exit(1)
# Out:
# Library version: 4.0.0.116
# Number of cameras detected: 1
# Running example for camera 0...
# *** DEVICE INFORMATION ***
#
# DeviceID: USB\VID_1E10&PID_4000&MI_00\6&2A5D0DF9&0&0000_0
# DeviceSerialNumber: 16290112
# DeviceUserID:
# DeviceVendorName: FLIR
# DeviceModelName: Blackfly S BFS-U3-13Y3M
# DeviceVersion: 1808.0.120.0
# DeviceBootloaderVersion: Node not readable
# DeviceType: USB3Vision
# DeviceDisplayName: FLIR Blackfly S BFS-U3-13Y3M
# DeviceAccessStatus: OpenReadWrite
# DeviceDriverVersion: PGRUSBCam3.sys : 2.7.3.249
# DeviceIsUpdater: 0
# DeviceInstanceId: USB\VID_1E10&PID_4000&MI_00\6&2A5D0DF9&0&0000
# DeviceLocation: 0000.0014.0000.021.000.000.000.000.000
# DeviceCurrentSpeed: SuperSpeed
# DeviceU3VProtocol: 1
# DevicePortId: 21
# GenICamXMLLocation: Device
# GenICamXMLPath:
# GUIXMLLocation: Device
# GUIXMLPath: Input.xml
# Trigger configured to hardware (Line3) with rising edge activation.
# Acquiring images...
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-0.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-1.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-2.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-3.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-4.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-5.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-6.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-7.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-8.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-9.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-10.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-12.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-13.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-14.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-15.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-16.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-17.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-18.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-19.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-20.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-21.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-22.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-23.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-24.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-25.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-26.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-27.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-28.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-29.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-30.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-31.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-32.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-33.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-34.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-35.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-36.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-37.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-38.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-39.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-40.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-41.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-42.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-43.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-44.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-45.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-46.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-47.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-48.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-49.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-50.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-51.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-52.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-53.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-54.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-55.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-56.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-57.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-58.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-59.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-60.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-61.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-62.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-63.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-64.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-65.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-66.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-67.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-68.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-69.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-70.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-71.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-72.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-73.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-74.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-75.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-76.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-77.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-78.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-79.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-80.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-81.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-82.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-83.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-84.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-85.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-86.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-87.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-88.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-89.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-90.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-91.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-92.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-93.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-94.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-95.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-96.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-97.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-98.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-99.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-100.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-101.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-102.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-103.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-104.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-105.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-106.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-107.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-108.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-109.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-110.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-111.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-112.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-113.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-114.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-115.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-116.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-117.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-118.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-119.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-120.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-121.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-122.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-123.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-124.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-125.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-126.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-127.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-128.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-129.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-130.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-131.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-132.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-133.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-134.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-135.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-136.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-137.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-138.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-139.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-140.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-141.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-142.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-143.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-144.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-145.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-146.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-147.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-148.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-149.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-150.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-151.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-152.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-153.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-154.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-155.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-156.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-157.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-158.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-159.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-160.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-161.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-162.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-163.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-164.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-165.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-166.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-167.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-168.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-169.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-170.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-171.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-172.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-173.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-174.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-175.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-176.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-177.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-178.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-179.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-180.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-181.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-182.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-183.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-184.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-185.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-186.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-187.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-188.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-189.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-190.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-191.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-192.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-193.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-194.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-195.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-196.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-197.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-198.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-199.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-200.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-201.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-202.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-203.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-204.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-205.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-206.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-207.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-208.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-209.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-210.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-211.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-212.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-213.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-214.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-215.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-216.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-217.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-218.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-219.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-220.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-221.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-222.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-223.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-224.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-225.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-226.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-227.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-228.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-229.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-230.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-231.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-232.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-233.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-234.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-235.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-236.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-237.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-238.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-239.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-240.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-241.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-242.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-243.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-244.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-245.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-246.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-247.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-248.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-249.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-250.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-251.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-252.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-253.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-254.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-255.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-256.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-257.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-258.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-259.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-260.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-261.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-262.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-263.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-264.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-265.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-266.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-267.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-268.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-269.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-270.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-271.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-272.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-273.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-274.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-275.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-276.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-277.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-278.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-279.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-280.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-281.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-282.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-283.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-284.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-285.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-286.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-287.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-288.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-289.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-290.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-291.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-292.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-293.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-294.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-295.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-296.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-297.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-298.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-299.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-300.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-301.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-302.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-303.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-304.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-305.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-306.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-307.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-308.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-309.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-310.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-311.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-312.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-313.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-314.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-315.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-316.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-317.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-318.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-319.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-320.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-321.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-322.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-323.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-324.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-325.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-326.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-327.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-328.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-329.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-330.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-331.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-332.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-333.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-334.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-335.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-336.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-337.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-338.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-339.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-340.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-341.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-342.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-343.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-344.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-345.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-346.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-347.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-348.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-349.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-350.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-351.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-352.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-353.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-354.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-355.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-356.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-357.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-358.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-359.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-360.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-361.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-362.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-363.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-364.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-365.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-366.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-367.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-368.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-369.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-370.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-371.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-372.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-373.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-374.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-375.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-376.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-377.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-378.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-379.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-380.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-381.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-382.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-383.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-384.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-385.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-386.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-387.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-388.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-389.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-390.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-391.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-392.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-393.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-394.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-395.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-396.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-397.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-398.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-399.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-400.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-401.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-402.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-403.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-404.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-405.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-406.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-407.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-408.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-409.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-410.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-411.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-412.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-413.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-414.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-415.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-416.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-417.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-418.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-419.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-420.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-421.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-422.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-423.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-424.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-425.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-426.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-427.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-428.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-429.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-430.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-431.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-432.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-433.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-434.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-435.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-436.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-437.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-438.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-439.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-440.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-441.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-442.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-443.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-444.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-445.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-446.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-447.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-448.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-449.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-450.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-451.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-452.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-453.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-454.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-455.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-456.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-457.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-458.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-459.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-460.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-461.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-462.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-463.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-464.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-465.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-466.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-467.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-468.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-469.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-470.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-471.jpg
# ...
# Image saved at Trigger-16290112-11844.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11845.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11846.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11847.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11848.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11849.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11850.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11851.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11852.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11853.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11854.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11855.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11856.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11857.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11858.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11859.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11860.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11861.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11862.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11863.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11864.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11865.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11866.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11867.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11868.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11869.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11870.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11871.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11872.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11873.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11874.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11875.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11876.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11877.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11878.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11879.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11880.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11881.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11882.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11883.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11884.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11885.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11886.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11887.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11888.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11889.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11890.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11891.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11892.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11893.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11894.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11895.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11896.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11897.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11898.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11899.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11900.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11901.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11902.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11903.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11904.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11905.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11906.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11907.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11908.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11909.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11910.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11911.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11912.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11913.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11914.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11915.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11916.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11917.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11918.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11919.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11920.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11921.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11922.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11923.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11924.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11925.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11926.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11927.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11928.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11929.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11930.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11931.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11932.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11933.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11934.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11935.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11936.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11937.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11938.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11939.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11940.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11941.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11942.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11943.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11944.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11945.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11946.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11947.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11948.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11949.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11950.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11951.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11952.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11953.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11954.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11955.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11956.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11957.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11958.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11959.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11960.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11961.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11962.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11963.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11964.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11965.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11966.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11967.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11968.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11969.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11970.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11971.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11972.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11973.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11974.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11975.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11976.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11977.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11978.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11979.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11980.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11981.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11982.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11983.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11984.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11985.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11986.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11987.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11988.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11989.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11990.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11991.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11992.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11993.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11994.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11995.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11996.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11997.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11998.jpg
# Waiting for hardware trigger...
# Image grabbed successfully.
# Image saved at Trigger-16290112-11999.jpg
# Trigger mode disabled.
# Camera 0 example complete...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
